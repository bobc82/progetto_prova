# %% [raw]
# Caricamento dataset Housing da file txt.
# Legenda colonne:
#  - CRIM: tasso di criminalità
#  - ZN: proporzione degli appezzamenti estesi per oltre 2300 mq
#  - INDUS: proporzione delle attività produttive non commerciali per superficie
#  - CHAS: variabile di prossimità al fiume Charles (1 se l'appezzamento è sul fiume, 0 altrimenti)
#  - NOX: concentrazione di monossido d'azoto
#  - RM: numero medio di stanze per abitazione
#  - AGE: proporzione delle unità occupate edificate prima del 1940
#  - DIS: distanze pesate da cinque centri produttivi di Boston
#  - RAD: indice di accessibilità alle autostrade radiali
#  - TAX: tassa sulla casa ogni 10k dollari di valore
#  - PTRATIO: rapporto studenti/insegnanti
#  - B: 1000(Bk-0,63)^2 dove Bk è la proporzione di afroamericani
#  - LSTAT: tasso di povertà nella popolazione
#  - MEDV: valore mediano dell'abitazione occupate in migliaia di dollari
#
# Mediante l'istruzione head visualizzo le prime 5 righe del dataset

# %%
import pandas as pd

df = pd.read_csv('C:\work\progetto_prova\progetto_prova\housing.data.txt', sep='\s+')
df.columns=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
df.head()
# Out:
#       CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 0  0.02731  0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0     17.8
# 1  0.02729  0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0     17.8
# 2  0.03237  0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0     18.7
# 3  0.06905  0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0     18.7
# 4  0.02985  0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222.0     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   9.14  21.6
# 1  392.83   4.03  34.7
# 2  394.63   2.94  33.4
# 3  396.90   5.33  36.2
# 4  394.12   5.21  28.7

# %% [raw]
# Visualizzo una serie di grafici per vedere che relazione c'è per ogni coppia di variabili. Mi interessa prevedere MEDV, quindi questa colonna dovrebbe essere sempre presente. Ora considero le colonne ['CRIM','ZN','INDUS','CHAS','MEDV']

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import scatterplotmatrix
cols = ['CRIM','ZN','INDUS','CHAS','MEDV']
scatterplotmatrix(df[cols].values,figsize=(10,8),names=cols,alpha=0.5)
plt.tight_layout()
plt.show()

# %% [raw]
# Stessa operazione di prima. Considero le colonne ['NOX','RM','AGE','DIS','MEDV']. Da notare che tra RM (numero medio di stanze per abitazione) e MEDV (valore dell'abitazione) potrebbe esserci un andamento lineare.

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import scatterplotmatrix
cols = ['NOX','RM','AGE','DIS','MEDV']
scatterplotmatrix(df[cols].values,figsize=(10,8),names=cols,alpha=0.5)
plt.tight_layout()
plt.show()

# %% [raw]
# Ora si considerano le colonne ['RAD','TAX','PTRATIO'] e per ognuna di esse si osserva la relazione con MEDV. In questo caso non vi è alcuna relazione.

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import scatterplotmatrix
cols = ['RAD','TAX','PTRATIO','MEDV']
scatterplotmatrix(df[cols].values,figsize=(10,8),names=cols,alpha=0.5)
plt.tight_layout()
plt.show()

# %% [raw]
# Qui invece si nota un andamento regolare tra LSTAT (tasso di povertà nella popolazione) e MEDV. Si osserva che al diminuire di LSTAT, MEDV cresce con un andamento regolare. Potrebbe essere un caso di regressione polinomiale

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import scatterplotmatrix
cols = ['B','LSTAT','MEDV']
scatterplotmatrix(df[cols].values,figsize=(10,8),names=cols,alpha=0.5)
plt.tight_layout()
plt.show()

# %% [raw]
# Ora si stampa la matrice delle covarianze. Dato che la nostra variabile target è rapprensentata da MEDV, è interessante notare come ci sia una correlazione abbastanza buona tra RM e MEDV (0.70). I coefficienti di correlazione possono assumere un valore compreso tra -1 e 1. Se il coefficiente è zero, non c'è alcuna correlazione tra le variabili.

# %%
from mlxtend.plotting import heatmap
import numpy as np
cols = ['NOX','RM','AGE','DIS','MEDV']
cm = np.corrcoef(df[cols].values.T)
hm = heatmap(cm,row_names=cols,column_names=cols)
plt.show()

# %% [raw]
# Qui si fa lo stesso per B ed LsTAT. Anche tra LSTAT e MEDV c'è una buona correlazione (in questo caso negativa, difatti si nota come al decrescere di una variabile, cresce l'altro valore).

# %%
from mlxtend.plotting import heatmap
import numpy as np
cols = ['B','LSTAT','MEDV']
cm = np.corrcoef(df[cols].values.T)
hm = heatmap(cm,row_names=cols,column_names=cols)
plt.show()

# %% [raw]
# In questo caso si prende in considerazione la caratteristica RM e si addestra un modello di regressione lineare semplice tra RM e MEDV. Mediante la funzione lin_regplot si stampa un grafico che contiene sia i valori reali (punti) che i valori predenti (ossia la retta di regressione).

# %%
def lin_regplot(X,y,model):
    plt.scatter(X,y)
    plt.plot(X,model.predict(X))
    return None
    
X=df[['RM']].values
print(X)
y=df['MEDV'].values

from sklearn.linear_model import LinearRegression
slr = LinearRegression()
slr.fit(X,y)
y_pred = slr.predict(X)
lin_regplot(X,y,slr)
plt.xlabel('Numero di stanze medio per abitazione')
plt.ylabel('Prezzo in migliaia di $')
plt.title('Regressione Lineare')
plt.show()

# %% [raw]
# Si addestra un modello di regressione lineare semplice tra RM e MEDV mediante la classe RANSACRegressor. Questo è un modello più robusto nel caso in cui ci siano valori anomali e vengono scartati tutti i punti che hanno una distanza superiore a 5 alla linea di regressione.

# %%
from sklearn.linear_model import RANSACRegressor
ransac = RANSACRegressor(LinearRegression(),max_trials=100,min_samples=50,loss='absolute_error', residual_threshold=5.0,random_state=0)
ransac.fit(X,y)
y_pred_ransac = ransac.predict(X)
lin_regplot(X,y,ransac)
plt.xlabel('Numero di stanze medio per abitazione')
plt.ylabel('Prezzo in migliaia di $')
plt.title('RANSAC')
plt.show()

# %% [raw]
# Adesso si serializzano i due modelli tramite la libreria pickle. Sarà utile per l'utilizzo dell'applicazione web implementata la quale richiederà in input un valore RM e fornirà il risultato predetto da ognuno dei due modelli senza ricaricare il dataset e rifare l'addestramento da capo.

# %%
import pickle
import os
dest = os.path.join('predictor','pkl_objects')
if not os.path.exists(dest):
    os.makedirs(dest)
pickle.dump(slr,open(os.path.join(dest, 'lin_regressor.pkl'), 'wb'), protocol=4)
pickle.dump(ransac,open(os.path.join(dest, 'ransac_regressor.pkl'), 'wb'), protocol=4)
